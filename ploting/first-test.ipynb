# %%
#Library importation
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Data calling
datac = pd.read_csv('/home/labmwl/bug/Github/spectrometer-mwl/Spectrogram Data/just-water-16x.csv', sep=',', header=0)
data1r = pd.read_csv('/home/labmwl/bug/Github/spectrometer-mwl/Spectrogram Data/1drop-r-16x-100ml.csv', sep=',', header=0)
data1b = pd.read_csv('/home/labmwl/bug/Github/spectrometer-mwl/Spectrogram Data/1drop-b-16x-100ml.csv', sep=',', header=0)
data10_100r = pd.read_csv('/home/labmwl/bug/Github/spectrometer-mwl/Spectrogram Data/10-100-r-16x-100ml.csv', sep=',', header=0)
data10_100b = pd.read_csv('/home/labmwl/bug/Github/spectrometer-mwl/Spectrogram Data/10-100-b-16x-100ml.csv', sep=',', header=0)
data1_100r = pd.read_csv('/home/labmwl/bug/Github/spectrometer-mwl/Spectrogram Data/1-100-r-16x-100ml.csv', sep=',', header=0)
data1_100b = pd.read_csv('/home/labmwl/bug/Github/spectrometer-mwl/Spectrogram Data/1-100-b-16x-100ml.csv', sep=',', header=0)

# %%
datac
# Out:
#                     time  415nm  445nm  480nm  515nm  555nm  590nm  630nm  \
# 0    2023-01-31 11:34:42   3004  12094   6477  15267  30186  32597  26232
# 1    2023-01-31 11:34:43   3112  12565   6713  15917  31400  33904  27282
# 2    2023-01-31 11:34:43   3106  12564   6709  15887  31360  33847  27239
# 3    2023-01-31 11:34:44   3116  12644   6736  15938  31573  33975  27420
# 4    2023-01-31 11:34:45   3090  12503   6659  15743  31197  33655  27373
# ..                   ...    ...    ...    ...    ...    ...    ...    ...
# 117  2023-01-31 11:35:55   2948  11779   6326  15078  29589  32341  25884
# 118  2023-01-31 11:35:56   2951  11784   6335  15094  29559  32320  25865
# 119  2023-01-31 11:35:56   2948  11772   6332  15091  29512  32277  25826
# 120  2023-01-31 11:35:57   2924  11677   6288  14997  29344  32078  25690
# 121  2023-01-31 11:35:58   2929  11738   6287  15048  29244  31978  25615
#
#      680nm  Clear   NIR
# 0    12424  65535  4966
# 1    12897  65535  5161
# ...

# %%
# Clear Water
labels = datac.columns.to_list()
labels = labels[1:]
clear_bars = []
col = ['purple','blue','cyan','lime','lawngreen','gold','darkorange','red','gray','crimson']
x = np.arange(len(labels))

for i in labels:
    clear_bars.append(np.mean(datac[i].to_numpy()))

fig, ax = plt.subplots(figsize=(10,6)) 

ax.bar(labels, clear_bars, align='center', color=col)
ax.set_xticks(x, labels, rotation=90)
plt.ylabel('Intensity')
plt.title('Clear Water')
for i in ax.containers:
    ax.bar_label(i)
plt.show()

fig.savefig('clear-water.png', facecolor=fig.get_facecolor(), edgecolor='none')

# %%
# 1 red drop
labels = data1r.columns.to_list()
labels = labels[1:]
bars = []
col = ['purple','blue','cyan','lime','lawngreen','gold','darkorange','red','gray','crimson']
x = np.arange(len(labels))

j = 0
for i in labels:
    bars.append(np.mean(data1r[i].to_numpy())-clear_bars[j])
    j += 1

fig, ax = plt.subplots(figsize=(10,6))

ax.bar(labels, bars, align='center', color=col)
ax.set_xticks(x, labels, rotation=90)
plt.ylabel('Intensity Diference From Clear Water')
plt.title('1 red drop (100ml)')
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

fig.savefig('1-drop-r.png', facecolor=fig.get_facecolor(), edgecolor='none')

# %%
# 1 blue drop
labels = data1b.columns.to_list()
labels = labels[1:]
bars = []
col = ['purple','blue','cyan','lime','lawngreen','gold','darkorange','red','gray','crimson']
x = np.arange(len(labels))

j = 0
for i in labels:
    bars.append(np.mean(data1b[i].to_numpy())-clear_bars[j])
    j += 1

fig, ax = plt.subplots(figsize=(10,6))

ax.bar(labels, bars, align='center', color=col)
ax.set_xticks(x, labels, rotation=90)
plt.ylabel('Intensity Diference From Clear Water')
plt.title('1 blue drop (100ml)')
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

fig.savefig('1-drop-b.png', facecolor=fig.get_facecolor(), edgecolor='none')

# %%
# 1/10 blue solution
labels = data10_100b.columns.to_list()
labels = labels[1:]
bars = []
col = ['purple','blue','cyan','lime','lawngreen','gold','darkorange','red','gray','crimson']
x = np.arange(len(labels))

j = 0
for i in labels:
    bars.append(np.mean(data10_100b[i].to_numpy())-clear_bars[j])
    j += 1
    
fig, ax = plt.subplots(figsize=(10,6))

ax.bar(labels, bars, align='center', color=col)
ax.set_xticks(x, labels, rotation=90)
plt.ylabel('Intensity Diference From Clear Water')
plt.title('1/10 blue solution (100ml)')
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

fig.savefig('1-10-b.png', facecolor=fig.get_facecolor(), edgecolor='none')

# %%
# 1/10 red solution
labels = data10_100r.columns.to_list()
labels = labels[1:]
bars = []
col = ['purple','blue','cyan','lime','lawngreen','gold','darkorange','red','gray','crimson']
x = np.arange(len(labels))

j = 0
for i in labels:
    bars.append(np.mean(data10_100r[i].to_numpy())-clear_bars[j])
    j += 1
    
fig, ax = plt.subplots(figsize=(10,6))

ax.bar(labels, bars, align='center', color=col)
ax.set_xticks(x, labels, rotation=90)
plt.ylabel('Intensity Diference From Clear Water')
plt.title('1/10 red solution (100ml)')
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

fig.savefig('1-10-r.png', facecolor=fig.get_facecolor(), edgecolor='none')

# %%
# 1/100 blue solution
labels = data1_100b.columns.to_list()
labels = labels[1:]
bars = []
col = ['purple','blue','cyan','lime','lawngreen','gold','darkorange','red','gray','crimson']
x = np.arange(len(labels))

j = 0
for i in labels:
    bars.append(np.mean(data1_100b[i].to_numpy())-clear_bars[j])
    j += 1

fig, ax = plt.subplots(figsize=(10,6))

ax.bar(labels, bars, align='center', color=col)
ax.set_xticks(x, labels, rotation=90)
plt.ylabel('Intensity Diference From Clear Water')
plt.title('1/100 blue solution (100ml)')
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

fig.savefig('1-100-b.png', facecolor=fig.get_facecolor(), edgecolor='none')

# %%
# 1/100 red solution
labels = data1_100r.columns.to_list()
labels = labels[1:]
bars = []
col = ['purple','blue','cyan','lime','lawngreen','gold','darkorange','red','gray','crimson']
x = np.arange(len(labels))

j = 0
for i in labels:
    bars.append(np.mean(data1_100r[i].to_numpy())-clear_bars[j])
    j += 1

fig, ax = plt.subplots(figsize=(10,6))

ax.bar(labels, bars, align='center', color=col)
ax.set_xticks(x, labels, rotation=90)
plt.ylabel('Intensity Diference From Clear Water')
plt.title('1/100 red solution (100ml)')
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

fig.savefig('1-100-r.png', facecolor=fig.get_facecolor(), edgecolor='none')
